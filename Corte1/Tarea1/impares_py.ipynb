# %% [markdown]
# <a href="https://colab.research.google.com/github/Mvic11/AP005-3-2026-3/blob/main/Corte1/Tarea1/impares_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# for i in range (1,21):  # Bucle comentado que recorrería números del 1 al 20
#     residual = i%2  # Calcula el residuo de dividir 'i' entre 2
#     if residual == 0:  # Si el residuo es 0, el número es par
#         print(f'{i} is even')  # Imprimiría que es par
#     else:  # Si el residuo no es 0, es impar
#         #print(f'{i} is odd')  # Línea comentada con f-string
#         print(str(i) + ' is odd')  # Imprimiría que es impar concatenando texto

# for i in range (0,6):  # Bucle comentado que recorrería números del 0 al 5
#     result = i**3  # Elevaría 'i' al cubo (i³)
#     print(result)  # Imprimiría el resultado del cubo

times = input("Enter a number of times: ")  # Pide un texto al usuario
times = float(times)  # Convierte el texto ingresado a decimal (float)
times = int(times)  # Trunca el decimal convirtiéndolo a entero
print(type(times))  # Muestra el tipo de dato final de 'times' (<class 'int'>)
print(times)  # Muestra el valor entero ingresado

if times == 0:  # Comprueba si el valor es igual a 0
    print("Don't do anything")  # Imprime un mensaje si es 0
else:  # Si el valor es diferente de 0
    for i in range(1, times + 1):  # Recorre números desde 1 hasta 'times'
        print("i = ", i)  # Muestra la iteración actual en pantalla
