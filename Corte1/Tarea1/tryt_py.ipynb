# %% [markdown]
# <a href="https://colab.research.google.com/github/Mvic11/AP005-3-2026-3/blob/main/Corte1/Tarea1/tryt_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_cool_variable = 7 + 8 == 11  # Evalúa la suma (15) y la compara con 11, guardando el resultado booleano (False)
print(my_cool_variable)  # Muestra en pantalla el valor booleano 'False'
