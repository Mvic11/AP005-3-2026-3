# %% [markdown]
# <a href="https://colab.research.google.com/github/Mvic11/AP005-3-2026-3/blob/main/Corte1/Tarea1/divisible12_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(100, 301):  # Recorre números de 100 a 300
    if (i % 12) != 0:     # Si 'i' NO es divisible por 12
        continue          # Salta al siguiente número
    print(i)              # Imprime el múltiplo de 12
